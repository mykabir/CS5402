# %% [markdown]
# <h1 align="center">  Homework: 6</h1>
# <h2 align="center"> CS 5402 </h2>
# <h3 align="center"> By: Md Yasin Kabir, email: mkdv6@mst.edu </h3>

# %%
# Importing necessary packages
from surprise import SVD
from surprise import NMF
from surprise import Dataset
from surprise import evaluate, print_perf
import os
from surprise import Reader
from surprise import KNNBasic
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib 
# %matplotlib inline

# %%
#load data from a file 
file_path = os.path.expanduser('restaurant_ratings.txt')
reader = Reader(line_format='user item rating timestamp', sep='\t')

# %%
# Question 5. SVD
data = Dataset.load_from_file(file_path, reader=reader)
data.split(n_folds=3)
algo = SVD()
perf = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.9440
# MAE:  0.7456
# ------------
# Fold 2
# RMSE: 0.9473
# MAE:  0.7477
# ------------
# Fold 3
# RMSE: 0.9415
# MAE:  0.7430
# ------------
# ------------
# Mean RMSE: 0.9443
# Mean MAE : 0.7454
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9440  0.9473  0.9415  0.9443
# MAE     0.7456  0.7477  0.7430  0.7454

# %%
# Question 6. PMF
data = Dataset.load_from_file(file_path, reader=reader)
data.split(n_folds=3)
algo = SVD(biased=False) #PMF
perf = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.9691
# MAE:  0.7660
# ------------
# Fold 2
# RMSE: 0.9612
# MAE:  0.7588
# ------------
# Fold 3
# RMSE: 0.9679
# MAE:  0.7635
# ------------
# ------------
# Mean RMSE: 0.9661
# Mean MAE : 0.7628
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9691  0.9612  0.9679  0.9661
# MAE     0.7660  0.7588  0.7635  0.7628

# %%
# Question 7. NMF
data = Dataset.load_from_file(file_path, reader=reader)
data.split(n_folds=3)
algo = NMF()
perf = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9770
# MAE:  0.7664
# ------------
# Fold 2
# RMSE: 0.9675
# MAE:  0.7604
# ------------
# Fold 3
# RMSE: 0.9770
# MAE:  0.7683
# ------------
# ------------
# Mean RMSE: 0.9739
# Mean MAE : 0.7650
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9770  0.9675  0.9770  0.9739
# MAE     0.7664  0.7604  0.7683  0.7650

# %%
# Question 8. User based collaborative filtering
data = Dataset.load_from_file(file_path, reader=reader)
data.split(n_folds=3)
algo = KNNBasic(sim_options = {
        'user_based': True 
        })
perf = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9841
# MAE:  0.7784
# ------------
# Fold 2
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9939
# MAE:  0.7868
# ------------
# Fold 3
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9922
# MAE:  0.7827
# ------------
# ------------
# Mean RMSE: 0.9901
# Mean MAE : 0.7827
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9841  0.9939  0.9922  0.9901
# MAE     0.7784  0.7868  0.7827  0.7827

# %%
# Question 9. Item based collaborative filtering
data = Dataset.load_from_file(file_path, reader=reader)
data.split(n_folds=3)
algo = KNNBasic(sim_options = {
                'user_based': False 
                })
perf = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9908
# MAE:  0.7849
# ------------
# Fold 2
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9831
# MAE:  0.7798
# ------------
# Fold 3
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9842
# MAE:  0.7783
# ------------
# ------------
# Mean RMSE: 0.9860
# Mean MAE : 0.7810
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9908  0.9831  0.9842  0.9860
# MAE     0.7849  0.7798  0.7783  0.7810

# %% [markdown]
# ### Question 10
# #### Using same data for all the algos

# %%
data = Dataset.load_from_file(file_path, reader=reader)
data.split(n_folds=3)

# %%
# SVD
algo = SVD()
perf_SVD = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_SVD)

#PMF
algo = SVD(biased=False) #PMF
perf_PMF = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_PMF)

#NMF
algo = NMF()
perf_NMF = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_NMF)

#User-based collaborative filtering
algo = KNNBasic(sim_options = {
        'user_based': True 
        })
perf_UserBased = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_UserBased)


#Item-based collaborative filtering
algo = KNNBasic(sim_options = {
                'user_based': False 
                })
perf_ItemBased = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_ItemBased)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.9434
# MAE:  0.7438
# ------------
# Fold 2
# RMSE: 0.9458
# MAE:  0.7473
# ------------
# Fold 3
# RMSE: 0.9445
# MAE:  0.7459
# ------------
# ------------
# Mean RMSE: 0.9446
# Mean MAE : 0.7457
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9434  0.9458  0.9445  0.9446
# MAE     0.7438  0.7473  0.7459  0.7457
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.9655
# MAE:  0.7606
# ------------
# Fold 2
# RMSE: 0.9670
# MAE:  0.7635
# ------------
# Fold 3
# RMSE: 0.9665
# MAE:  0.7619
# ------------
# ------------
# Mean RMSE: 0.9663
# Mean MAE : 0.7620
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9655  0.9670  0.9665  0.9663
# MAE     0.7606  0.7635  0.7619  0.7620
# Evaluating RMSE, MAE of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9703
# MAE:  0.7620
# ------------
# Fold 2
# RMSE: 0.9781
# MAE:  0.7703
# ------------
# Fold 3
# RMSE: 0.9776
# MAE:  0.7687
# ------------
# ------------
# Mean RMSE: 0.9753
# Mean MAE : 0.7670
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9703  0.9781  0.9776  0.9753
# MAE     0.7620  0.7703  0.7687  0.7670
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9866
# MAE:  0.7802
# ------------
# Fold 2
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9902
# MAE:  0.7829
# ------------
# Fold 3
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9894
# MAE:  0.7818
# ------------
# ------------
# Mean RMSE: 0.9887
# Mean MAE : 0.7816
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9866  0.9902  0.9894  0.9887
# MAE     0.7802  0.7829  0.7818  0.7816
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9798
# MAE:  0.7758
# ------------
# Fold 2
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9856
# MAE:  0.7810
# ------------
# Fold 3
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9893
# MAE:  0.7845
# ------------
# ------------
# Mean RMSE: 0.9849
# Mean MAE : 0.7804
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9798  0.9856  0.9893  0.9849
# MAE     0.7758  0.7810  0.7845  0.7804

# %%
# Question 10-13. Printing the performance evaluation for all 3 folds and mean
print_perf(perf_UserBased)
print_perf(perf_ItemBased)
print_perf(perf_SVD)
print_perf(perf_PMF)
print_perf(perf_NMF)
# Out:
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9866  0.9902  0.9894  0.9887
# MAE     0.7802  0.7829  0.7818  0.7816
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9798  0.9856  0.9893  0.9849
# MAE     0.7758  0.7810  0.7845  0.7804
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9434  0.9458  0.9445  0.9446
# MAE     0.7438  0.7473  0.7459  0.7457
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9655  0.9670  0.9665  0.9663
# MAE     0.7606  0.7635  0.7619  0.7620
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9703  0.9781  0.9776  0.9753
# MAE     0.7620  0.7703  0.7687  0.7670

# %%
# Question 14
#User-based collaborative filtering. MSD
algo = KNNBasic(sim_options = {
        'name': 'MSD',
        'user_based': True 
        })
perf_UserBased_MSD = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_UserBased_MSD)

#User-based collaborative filtering. Cosine
algo = KNNBasic(sim_options = {
        'name': 'cosine',
        'user_based': True 
        })
perf_UserBased_cosine = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_UserBased_cosine)

#User-based collaborative filtering. Pearson.
algo = KNNBasic(sim_options = {
        'name': 'pearson',
        'user_based': True 
        })
perf_UserBased_pearson = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_UserBased_pearson)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9866
# MAE:  0.7802
# ------------
# Fold 2
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9902
# MAE:  0.7829
# ------------
# Fold 3
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9894
# MAE:  0.7818
# ------------
# ------------
# Mean RMSE: 0.9887
# Mean MAE : 0.7816
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9866  0.9902  0.9894  0.9887
# MAE     0.7802  0.7829  0.7818  0.7816
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0196
# MAE:  0.8077
# ------------
# Fold 2
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0242
# MAE:  0.8111
# ------------
# Fold 3
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0222
# MAE:  0.8087
# ------------
# ------------
# Mean RMSE: 1.0220
# Mean MAE : 0.8092
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0196  1.0242  1.0222  1.0220
# MAE     0.8077  0.8111  0.8087  0.8092
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0165
# MAE:  0.8079
# ------------
# Fold 2
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0236
# MAE:  0.8124
# ------------
# Fold 3
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0247
# MAE:  0.8126
# ------------
# ------------
# Mean RMSE: 1.0216
# Mean MAE : 0.8110
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0165  1.0236  1.0247  1.0216
# MAE     0.8079  0.8124  0.8126  0.8110

# %%
# Question 14
# Item-based collaborative filtering. MSD. 
algo = KNNBasic(sim_options = {
        'name': 'MSD',
        'user_based': False 
        })
perf_ItemBased_MSD = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_ItemBased_MSD)

# Item-based collaborative filtering. Cosine. 
algo = KNNBasic(sim_options = {
        'name': 'cosine',
        'user_based': False 
        })
perf_ItemBased_cosine = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_ItemBased_cosine)

# Item-based collaborative filtering. Pearson. 
algo = KNNBasic(sim_options = {
        'name': 'pearson',
        'user_based': False 
        })
perf_ItemBased_pearson = evaluate(algo, data, measures=['RMSE', 'MAE'])
print_perf(perf_ItemBased_pearson)
# Out:
# Evaluating RMSE, MAE of algorithm KNNBasic.
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# ------------
# Fold 1
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9798
# MAE:  0.7758
# ------------
# Fold 2
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9856
# MAE:  0.7810
# ------------
# Fold 3
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9893
# MAE:  0.7845
# ------------
# ------------
# Mean RMSE: 0.9849
# Mean MAE : 0.7804
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9798  0.9856  0.9893  0.9849
# MAE     0.7758  0.7810  0.7845  0.7804
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0292
# MAE:  0.8162
# ------------
# Fold 2
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0370
# MAE:  0.8231
# ------------
# Fold 3
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0395
# MAE:  0.8266
# ------------
# ------------
# Mean RMSE: 1.0352
# Mean MAE : 0.8220
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0292  1.0370  1.0395  1.0352
# MAE     0.8162  0.8231  0.8266  0.8220
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0410
# MAE:  0.8329
# ------------
# Fold 2
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0496
# MAE:  0.8396
# ------------
# Fold 3
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0542
# MAE:  0.8443
# ------------
# ------------
# Mean RMSE: 1.0483
# Mean MAE : 0.8389
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0410  1.0496  1.0542  1.0483
# MAE     0.8329  0.8396  0.8443  0.8389

# %%
vals = [np.mean(perf_UserBased_MSD['mae']), np.mean(perf_UserBased_cosine['mae']), np.mean(perf_UserBased_pearson['mae'])]
metrics = np.array(['MSD', 'cosine', 'pearson'])
series = pd.Series(name='MAE', data=vals)
ax = sns.barplot(metrics, series.values)
ax.set_title("Similarity Metrics Comparison: User Based- MAE")
ax.set_ylabel('MAE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.7, 0.9)
plt.show()
print(vals)

vals = [np.mean(perf_UserBased_MSD['rmse']), np.mean(perf_UserBased_cosine['rmse']), np.mean(perf_UserBased_pearson['rmse'])]
metrics = np.array(['MSD', 'cosine', 'pearson'])
series = pd.Series(name='MAE', data=vals)
ax = sns.barplot(metrics, series.values)
ax.set_title("Similarity Metrics Comparison: User Based- RMSE")
ax.set_ylabel('MAE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.9,1.1)
plt.show()
print(vals)

vals = [np.mean(perf_ItemBased_MSD['mae']), np.mean(perf_ItemBased_cosine['mae']), np.mean(perf_ItemBased_pearson['mae'])]
metrics = np.array(['MSD', 'cosine', 'pearson'])
series = pd.Series(name='MAE', data=vals)
ax = sns.barplot(metrics, series.values)
ax.set_title("Similarity Metrics Comparison: Item Based- MAE")
ax.set_ylabel('MAE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.7, 0.9)
plt.show()
print(vals)

vals = [np.mean(perf_ItemBased_MSD['rmse']), np.mean(perf_ItemBased_cosine['rmse']), np.mean(perf_ItemBased_pearson['rmse'])]
metrics = np.array(['MSD', 'cosine', 'pearson'])
series = pd.Series(name='MAE', data=vals)
ax = sns.barplot(metrics, series.values)
ax.set_title("Similarity Metrics Comparison: Item Based- RMSE")
ax.set_ylabel('MAE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.9,1.1)
plt.show()
print(vals)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# [0.7816440856035684, 0.8091648099682502, 0.8109581041584439]
# [0.9887305072580735, 1.0220090334489538, 1.0215825790296185]
# [0.7804376085444701, 0.8219708541480474, 0.8389212562024947]
# [0.9849103712256121, 1.0352405912129208, 1.0482696081770972]

# %%
#Question 15 
#Finding best K for User Based collaborative filtering
user_Based_RMSE_of_different_k = []
user_Based_MAE_of_different_k = []
for i in range(1,30):
    algo = KNNBasic(k=i, sim_options = {
            'name': 'MSD',
            'user_based': True 
            })
    perf_UserBased_MSD = evaluate(algo, data, measures=['RMSE', 'MAE'], verbose=0)
    print("________________________________")
    print("K= ", i)
    print_perf(perf_UserBased_MSD)
    user_Based_MAE_of_different_k.append(np.mean(perf_UserBased_MSD['mae']))
    user_Based_RMSE_of_different_k.append(np.mean(perf_UserBased_MSD['rmse']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  1
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.3238  1.3295  1.3289  1.3274
# MAE     0.9747  0.9825  0.9839  0.9804
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  2
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.1502  1.1516  1.1541  1.1520
# MAE     0.8866  0.8900  0.8943  0.8903
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  3
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0912  1.0890  1.0899  1.0900
# MAE     0.8514  0.8502  0.8549  0.8521
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  4
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0600  1.0548  1.0588  1.0579
# MAE     0.8313  0.8263  0.8332  0.8303
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  5
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0410  1.0345  1.0417  1.0390
# MAE     0.8178  0.8119  0.8203  0.8167
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  6
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0296  1.0202  1.0264  1.0254
# MAE     0.8110  0.8011  0.8098  0.8073
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  7
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0189  1.0103  1.0175  1.0156
# MAE     0.8031  0.7940  0.8033  0.8001
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  8
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0131  1.0035  1.0110  1.0092
# MAE     0.7984  0.7892  0.7984  0.7953
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  9
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0086  0.9980  1.0056  1.0041
# MAE     0.7951  0.7852  0.7940  0.7914
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  10
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0044  0.9944  1.0021  1.0003
# MAE     0.7920  0.7827  0.7917  0.7888
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  11
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0014  0.9916  0.9990  0.9973
# MAE     0.7897  0.7805  0.7887  0.7863
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  12
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9990  0.9896  0.9965  0.9950
# MAE     0.7882  0.7787  0.7867  0.7846
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  13
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9971  0.9880  0.9945  0.9932
# MAE     0.7870  0.7776  0.7851  0.7832
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  14
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9958  0.9867  0.9930  0.9918
# MAE     0.7859  0.7770  0.7840  0.7823
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  15
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9948  0.9856  0.9916  0.9907
# MAE     0.7849  0.7759  0.7829  0.7812
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  16
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9936  0.9850  0.9906  0.9897
# MAE     0.7839  0.7756  0.7823  0.7806
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  17
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9930  0.9838  0.9898  0.9889
# MAE     0.7835  0.7748  0.7815  0.7799
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  18
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9925  0.9828  0.9893  0.9882
# MAE     0.7834  0.7742  0.7808  0.7795
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  19
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9924  0.9823  0.9888  0.9878
# MAE     0.7833  0.7739  0.7805  0.7793
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  20
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9922  0.9818  0.9889  0.9876
# MAE     0.7832  0.7736  0.7806  0.7791
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  21
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9919  0.9814  0.9885  0.9873
# MAE     0.7832  0.7734  0.7804  0.7790
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  22
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9917  0.9812  0.9883  0.9871
# MAE     0.7831  0.7730  0.7802  0.7788
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  23
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9914  0.9811  0.9884  0.9870
# MAE     0.7831  0.7732  0.7800  0.7788
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  24
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9911  0.9809  0.9884  0.9868
# MAE     0.7828  0.7732  0.7801  0.7787
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  25
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9910  0.9809  0.9883  0.9867
# MAE     0.7828  0.7733  0.7801  0.7787
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  26
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9912  0.9808  0.9883  0.9868
# MAE     0.7830  0.7733  0.7803  0.7788
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  27
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9913  0.9809  0.9883  0.9869
# MAE     0.7830  0.7735  0.7802  0.7789
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  28
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9915  0.9812  0.9884  0.9871
# MAE     0.7833  0.7739  0.7804  0.7792
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  29
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9915  0.9811  0.9886  0.9871
# MAE     0.7833  0.7739  0.7808  0.7793

# %%
# Question 15 
# Finding best K for Item Based collaborative filtering
item_Based_RMSE_of_different_k = []
item_Based_MAE_of_different_k = []
for i in range(1,30):
    algo = KNNBasic(k=i, sim_options = {
            'name': 'MSD',
            'user_based': False 
            })
    perf_ItemBased_MSD = evaluate(algo, data, measures=['RMSE', 'MAE'], verbose=0)
    print("________________________________")
    print("K= ", i)
    print_perf(perf_ItemBased_MSD)
    item_Based_MAE_of_different_k.append(np.mean(perf_ItemBased_MSD['mae']))
    item_Based_RMSE_of_different_k.append(np.mean(perf_ItemBased_MSD['rmse']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  1
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.4303  1.4304  1.4354  1.4320
# MAE     1.0576  1.0577  1.0606  1.0586
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  2
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.2295  1.2322  1.2431  1.2349
# MAE     0.9478  0.9519  0.9610  0.9536
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  3
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.1534  1.1529  1.1614  1.1559
# MAE     0.8993  0.9005  0.9095  0.9031
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  4
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.1133  1.1090  1.1182  1.1135
# MAE     0.8724  0.8712  0.8806  0.8747
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  5
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0854  1.0801  1.0911  1.0855
# MAE     0.8535  0.8513  0.8612  0.8554
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  6
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0663  1.0606  1.0704  1.0658
# MAE     0.8398  0.8379  0.8467  0.8415
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  7
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0525  1.0461  1.0549  1.0512
# MAE     0.8296  0.8270  0.8350  0.8305
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  8
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0415  1.0347  1.0441  1.0401
# MAE     0.8213  0.8190  0.8266  0.8223
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  9
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0324  1.0263  1.0357  1.0315
# MAE     0.8141  0.8122  0.8202  0.8155
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  10
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0252  1.0194  1.0279  1.0242
# MAE     0.8085  0.8070  0.8144  0.8100
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  11
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0199  1.0139  1.0213  1.0184
# MAE     0.8047  0.8028  0.8094  0.8056
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  12
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0151  1.0091  1.0169  1.0137
# MAE     0.8013  0.7990  0.8063  0.8022
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  13
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0109  1.0051  1.0128  1.0096
# MAE     0.7982  0.7959  0.8029  0.7990
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  14
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0074  1.0025  1.0098  1.0066
# MAE     0.7953  0.7937  0.8006  0.7966
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  15
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0046  0.9999  1.0068  1.0038
# MAE     0.7930  0.7915  0.7984  0.7943
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  16
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    1.0021  0.9971  1.0045  1.0012
# MAE     0.7907  0.7893  0.7967  0.7922
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  17
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9998  0.9948  1.0031  0.9992
# MAE     0.7890  0.7875  0.7956  0.7907
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  18
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9981  0.9930  1.0013  0.9974
# MAE     0.7874  0.7859  0.7942  0.7892
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  19
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9961  0.9909  0.9996  0.9955
# MAE     0.7858  0.7843  0.7929  0.7876
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  20
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9950  0.9895  0.9982  0.9943
# MAE     0.7852  0.7833  0.7917  0.7867
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  21
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9937  0.9883  0.9974  0.9931
# MAE     0.7841  0.7822  0.7911  0.7858
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  22
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9930  0.9873  0.9965  0.9923
# MAE     0.7837  0.7814  0.7904  0.7852
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  23
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9924  0.9869  0.9959  0.9917
# MAE     0.7833  0.7811  0.7900  0.7848
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  24
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9915  0.9860  0.9949  0.9908
# MAE     0.7827  0.7803  0.7892  0.7841
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  25
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9910  0.9850  0.9943  0.9901
# MAE     0.7824  0.7796  0.7888  0.7836
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  26
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9903  0.9844  0.9938  0.9895
# MAE     0.7819  0.7791  0.7885  0.7832
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  27
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9899  0.9836  0.9933  0.9889
# MAE     0.7816  0.7784  0.7881  0.7827
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  28
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9895  0.9833  0.9928  0.9885
# MAE     0.7814  0.7784  0.7877  0.7825
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ________________________________
# K=  29
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9894  0.9829  0.9925  0.9883
# MAE     0.7812  0.7782  0.7875  0.7823

# %%
#Best RMSE for User Based Collaborative filtering
min_RMSE_index = np.argmin(user_Based_RMSE_of_different_k)
print("Best K= ", min_RMSE_index)
print("Best RMSE= ", np.min(user_Based_RMSE_of_different_k))
# Out:
# Best K=  24
# Best RMSE=  0.9867139009612268

# %%
# Rmse Chart for User Based Collaborative filtering
series = pd.Series(name='rmse', data=user_Based_RMSE_of_different_k)
ax = sns.barplot(series.index, series.values)
ax.set_ylabel('RMSE values')
ax.set_xlabel('Number of K')
ax.set_xlim(1, 30)
ax.set_ylim(.7, 1.2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# (0.7, 1.2)

# %%
#Best RMSE for User Based Collaborative filtering
min_RMSE_index = np.argmin(item_Based_RMSE_of_different_k)
print("Best K= ", min_RMSE_index)
print("Best RMSE= ", np.min(item_Based_RMSE_of_different_k))
# Out:
# Best K=  28
# Best RMSE=  0.9882758706490519

# %%
#RMSE value for K = 24
item_Based_RMSE_of_different_k[24]
# Out:
# 0.9901309251416883

# %%
# Rmse Chart for Item Based Collaborative filtering
series = pd.Series(name='rmse', data=item_Based_RMSE_of_different_k)
ax = sns.barplot(series.index, series.values)
ax.set_ylabel('RMSE')
ax.set_xlabel('k')
ax.set_xlim(1, 30)
ax.set_ylim(.8, 1.2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# (0.8, 1.2)
